# %%
import xmltodict
import pandas as pd
from pathlib import Path

def create_dict_from_xml(chemin_fichier):
    with open(chemin_fichier, encoding='utf8') as fd:
        doc = xmltodict.parse(fd.read(), dict_constructor=dict)
    return doc

# %%
"""
  Parse le dictionnaire des types complexes et retourne le résultat dans un dataframe et un dictionnaire
"""

def _parse_complex_type(annexe_type : dict):
    list_records = []
    all_complex_type = annexe_type['xs:schema']['xs:complexType']
    i=0
    for complex_type in all_complex_type:
        temp_dict = dict()
        nom_type_complexe = complex_type['@name']
        if isinstance(complex_type['xs:attribute'], dict):
            for element in complex_type['xs:attribute']['xs:simpleType']['xs:restriction']['xs:enumeration']:
                temp_dict[element['@value']] = element.get('xs:annotation', {}).get('xs:documentation', element['@value'])
        
        result_dict = {
            "type" : nom_type_complexe,
            "enum" : temp_dict
        }
        list_records.append(result_dict)
    
    df = pd.DataFrame.from_records(list_records)

    return df

def _generate_complex_type_df(chemin : Path) -> pd.DataFrame:
    annexe_type = create_dict_from_xml(chemin)
    complexe_types_df = _parse_complex_type(annexe_type)
    
    return complexe_types_df

"""
  Génération d'une documentation des codes de données des annexes
"""
def _make_dict_champs(element: dict, nom_annexe: str) -> dict:
    documentation = element['xs:annotation']['xs:documentation']
    if isinstance(documentation, str):
        libelle = documentation
        description = documentation
    else:
        libelle = element['xs:annotation']['xs:documentation']['z:libelle']
        description = element['xs:annotation']['xs:documentation'].get('z:description')
    dict_champs = {
        "nom_annexe" : nom_annexe,
        "nom_champ" : element["@name"],
        "type" : element["@type"],
        "libelle" : libelle,
        "description" : description,
    }
    return dict_champs

def _parse_annexe_fields_documentation(class_annexe : dict) -> pd.DataFrame:
    elements = class_annexe['xs:sequence']['xs:element']
    list_records = []
    dict_champs = dict()
    nom_annexe = class_annexe["@name"][1:]
    
    for element in elements:
        dict_champs = _make_dict_champs(element, nom_annexe)
        list_records.append(dict_champs)
    
    df = pd.DataFrame.from_records(list_records)
    df["description"] = df["description"].str.replace(r'^<[^<>]*>', '', regex=True)
    df["description"] = df["description"].str.replace(r'^\s*<ul>', '', regex=True)
    df["description"] = df["description"].str.replace(r'^\s*<li>', '', regex=True)
    df["description"] = df["description"].str.replace(r'<ul>', ' : ', regex=True)
    df["description"] = df["description"].str.replace(r'<li>', ' - ', regex=True)
    df["description"] = df["description"].str.replace(r'<[^<>]*>', ' ', regex=True)
    df["description"] = df["description"].str.replace(r'\s\s+', ' ', regex=True)
        
    return df

def _merge_annexe_type_and_documentation(chemin_annexe: Path, complex_type_df: pd.DataFrame) -> pd.DataFrame:
    class_to_generate = create_dict_from_xml(chemin_annexe)['xs:schema']['xs:complexType'][1]
    init_df = _parse_annexe_fields_documentation(class_to_generate)
    init_df = init_df.merge(complex_type_df, how='left')
    return init_df

from pathlib import Path
PATH_TO_SCHEMA = Path("./schemas/")

def _get_list_annexes_path():
    dict_annexe = create_dict_from_xml(PATH_TO_SCHEMA.joinpath("SchemaDocBudg/Class_Annexes.xsd"))["xs:schema"]['xs:include']
    dict_annexe.pop(0)
    class_annexe_paths = []
    for annexe in dict_annexe: 
        class_annexe_paths.append(PATH_TO_SCHEMA.joinpath(f"SchemaDocBudg/{annexe['@schemaLocation']}"))
    return class_annexe_paths


def _parse_all_annexes_fields_documentation() -> pd.DataFrame:
    #Erreurs à traiter manuellement :
    # - l'annexe signatures dont la balise xs:complextype est inversée par rapport à l'habitude, il faut copier le premier bloc xs:complextype en dessous du 2ème.
    #       + suppression deux balises complexes types signataires (nested?)
    # - l'annexe emprunt "IndSousJacentDtVote" ou il y a deux balises documentation qui génère une liste (seul cas)
    df_result = pd.DataFrame()
    
    annexes_paths = _get_list_annexes_path()
    annexe_complexe_types = _generate_complex_type_df(PATH_TO_SCHEMA.joinpath("SchemaDocBudg/CommunAnnexe.xsd"))
    
    for annexe_path in annexes_paths:
        df = _merge_annexe_type_and_documentation(annexe_path, annexe_complexe_types)
        df_result = pd.concat([df, df_result])
    
    return df_result.set_index('nom_champ')


def generate_annexe_data_documentation_csv(path_to_export : Path):
    df_to_csv = _parse_all_annexes_fields_documentation()
    generate_csv(path_to_export, df_to_csv)  
    

def generate_csv(path_to_export : Path, df_to_csv : pd.DataFrame):
    df_to_csv.to_csv(path_to_export, index=False)

# %%
# 1 - récupération des champs spéciaux
#Quid des données obsolètes ?
# A gérer le cas de CodMotifContrAgent (nested documentation)
to_replace = _parse_all_annexes_fields_documentation()["enum"]   \
                                        .dropna()  \
                                        .to_dict()

# %%
to_replace
# Out:
# {'CodNatOpe': {'14': 'Etudes et conduite de projet',
#   '15': 'Relogement des ménages avec minoration de loyer',
#   '21': 'Démolition de logements locatifs sociaux',
#   '22': 'Recyclage de copropriétés dégradées',
#   '23': "Recyclage de l'habitat ancien dégradé",
#   '24': 'Aménagement d’ensemble',
#   '31': "Reconstitution de l'offre de logements locatifs sociaux",
#   '32': "Production d'une offre de relogement temporaire",
#   '33': 'Requalification de logements locatifs sociaux',
#   '34': 'Résidentialisation de logements',
#   '35': 'Actions de portage massif en copropriétés dégradées',
#   '36': 'Accession à la propriété',
#   '37': 'Equipement public de proximité',
#   '38': 'Immobilier à vocation économique',
#   '39': 'Autres investissements',
#   '41': 'Quartiers Fertiles-Opérations d’ingénierie et dépenses de personnel',
#   '42': 'Quartiers Fertiles-Opérations d’investissement'},
#  'CodRD': {'R': 'Recette', 'D': 'Dépense'},
#  'CodTypFlux': {'01': 'Flux réciproques entre le groupement à fiscalité propre et les communes',
#   '02': 'Présentation consolidée du groupement à fiscalité propre et des communes (après ma neutralisation des flux)'},
#  'CodInvFonc': {'I': 'Investissement', 'F': 'Fonctionnement'},
#  'CodRDTot': {'R': 'Recette', 'D': 'Dépense'},
#  'CodRessExt': {'O': 'Oui', 'N': 'Non'},
#  'CodApprent': {'01': 'Apprentissage',
#   '02': 'Enseignement professionnel',
#   '03': 'Formations continues',
#   '04': 'Première section FNDMA',
#   '05': 'Seconde section FNDMA',
#   '06': 'Dotation décentralisation',
#   '07': 'Dotation indemnité compensatoire forfaitaire',
#   '08': 'Contribution additionnelle',
#   '09': 'FSE',
#   '10': 'FEDER',
#   '11': 'FEOGA',
#   '12': 'Reversement excédent de ressources CFA',
#   '13': 'Autres ressources',
#   '14': 'Effort propre de la région'},
#  'CodInvFon': {'I': 'Investissement', 'F': 'Fonctionnement'},
#  'TypeGestion': {'1': 'AP/AE', '2': 'Crédits de paiement'},
#  'TypeFonds': {'01': 'FEDER',
#   '02': 'FSE',
#   '03': 'FEADER',
#   '04': 'Autres fonds',
#   '05': 'Assistance technique'},
#  'CodDestFonds': {'01': 'Au titre des mesures gérées sous forme de subvention globales',
#   '02': "Au titre de l'assistance technique"},
#  'CodRDDJust': {'R': 'Recette', 'D': 'Dépense', 'DJ': 'Dépense justifiée'},
#  'CodCptTER': {'01': 'Produits du trafic',
#   '02': 'Produits annexes au trafic',
#   '03': 'Compensations des réductions tarifaires',
#   '04': 'Travaux pour Tiers',
#   '05': 'Produits hors trafic',
#   '06': 'Versements des collectivités',
#   '07': 'Production immobilisée et stockée',
#   '08': 'Personnel masse salariale',
#   '09': 'Consommations intermédiaires',
#   '10': 'Péage RFF',
#   '11': 'Impôts, taxes et versements assimilés',
#   '12': 'Achats stockés',
#   '13': 'Impôts et taxes hors FAP',
#   '14': 'Maintenance matériel roulant',
#   '15': 'Traction trains, conduite et logistique',
#   '16': 'Echange de locomotives entre activités',
#   '17': 'Energie de traction électrique',
#   '18': 'Energie de traction diesel',
#   '19': 'Entretien maintenance des installations fixes',
#   '20': 'Prestations télécoms',
#   '21': 'Echange de matériel roulant entre activités',
#   '22': 'Prestations trains',
#   '23': 'Contribution de service Activité Gare',
#   '24': 'Transport en service',
#   '25': 'Etablissements autres que EEX',
#   '26': 'Etablissements EEX',
#   '27': 'Autres facturations',
#   '28': 'Contributions aux ECE',
#   '29': 'Dotations aux amortissements',
#   '30': 'Reprise de subvention et écart de réévaluation',
#   '31': 'Variation des provisions / transfert de charge',
#   '32': 'Autres produits et charges de gestion courante',
#   '33': 'Résultat financier',
#   '34': 'Résultat exceptionnel / spécifique'},
#  'CodRegroupBudFerrov': {'01': "Contribution régionale d'équilibre d'exploitation TTC",
#   '02': "Compensation fiancière versée par l'Etat au titre de l'exploitation",
#   '03': "Compensation financière au titre des tarifs sociaux fixés par l'Etat",
#   '04': 'Matériel',
#   '99': 'Autres'},
#  'CodTyptxInit': {'F': 'Fixe',
#   'V': 'Variable simple',
#   'R': 'Préfixé',
#   'C': 'Complexe'},
#  'CodProfilAmort': {'C': 'Amortissement constant',
#   'P': 'Amortissement progressif',
#   'F': 'In fine',
#   'X': 'Autre'},
#  'CodTypPret': {'A': "Assortis d'intérêts", 'N': "Non assortis d'intérêts"},
#  'CodNatEtab': {'01': 'Etablissement public créé',
#   '02': 'Service individualisé dans un budget annexe',
#   '03': 'Service assujeti à la TVA et non érigé en budget annexe'},
#  'CodTypAutori': {'P': 'Autorisation de programme',
#   'E': "Autorisation d'engagement"},
#  'CodSTypAutori': {'S': 'Situation', 'R': 'Ratio'},
#  'TypeChapitre': {'1': 'Chapitre nature',
#   '2': 'Chapitre opérations pour comptes de tiers',
#   '3': 'Chapitre opérations d’équipement'},
#  'CodTypTabProv': {'E': 'Etat', 'L': 'Etalement ou provisions nouvelles'},
#  'CodTypProv': {'B': 'Provisions budgétaires',
#   'S': 'Provisions semi-budgétaires'},
#  'CodSTypProv': {'R': 'Risques et charges',
#   'D': 'Dépréciations',
#   'G': 'Provisions réglementées et amortissements dérogatoires'},
#  'CodNatProv': {'L': 'Provisions pour litiges',
#   'P': 'Provisions pour pertes de changes',
#   'G': "Provisions pour garanties d'emprunts",
#   'E': 'Provisions pour gros entretiens ou grandes révisions',
#   'A': 'Autres provisions pour risques',
#   'I': 'Provisions pour dépreciations des immobilisations',
#   'S': 'Provisions pour dépréciations des stocks et encours',
#   'C': 'Provisions pour dépréciations des comptes de tiers',
#   'F': 'Provisions pour dépréciations des comptes financiers'},
#  'ProcAmort': {'L': 'Linéaire', 'D': 'Dégressif', 'V': 'Variable'},
#  'CodTypTx': {'F': 'Fixe', 'V': 'Variable simple', 'C': 'Complexe'},
#  'CodTypRisqFinanc': {'I': "Relatifs aux taux d'intérêts",
#   'C': 'Relatifs aux taux de change'},
#  'CodPeriodRemb': {'M': 'Mensuelle',
#   'I': 'Trimestrielle',
#   'S': 'Semestrielle',
#   'A': 'Annuelle',
#   'X': 'Autre',
#   'B': 'Bimestrielle'},
#  'StuctureAvantCouv': {'A': 'Taux fixe ou taux variable simple',
#   'B': 'Barrière simple',
#   'C': "Option d'échange (swap)",
#   'D': 'Multiplicateur jusqu’à 3 ou 5 capé',
#   'E': 'Multiplicateur jusqu’à 5',
#   'F': 'Autre type de structure'},
#  'StuctureApresCouv': {'A': 'Taux fixe ou taux variable simple',
#   'B': 'Barrière simple',
#   'C': "Option d'échange (swap)",
#   'D': 'Multiplicateur jusqu’à 3 ou 5 capé',
#   'E': 'Multiplicateur jusqu’à 5',
#   'F': 'Autre type de structure'},
#  'IndSousJacentAvantCouv': {'1': 'Indices en euro',
#   '2': 'Indices inflation française ou zone euro',
#   '3': 'Ecarts d’indice zone euro',
#   '4': 'Indices hors zone euro',
#   '5': 'Ecarts d’indice hors zone euro',
#   '6': 'Autres indices'},
#  'IndSousJacentApresCouv': {'1': 'Indices en euro',
#   '2': 'Indices inflation française ou zone euro',
#   '3': 'Ecarts d’indice zone euro',
#   '4': 'Indices hors zone euro',
#   '5': 'Ecarts d’indice hors zone euro',
#   '6': 'Autres indices'},
#  'CodTypVentil': {'R': 'Répartition de la TEOM',
#   'A': 'Assainissement collectif/non collectif',
#   'E': 'Eau et assainissement',
#   'V': 'Services assujettis à la TVA',
#   'G': 'Travaux en régie',
#   'C': 'COVID-19'},
#  'TypOpBudg': {'O': 'Ordre', 'R': 'Réel'},
#  'CodRegroup': {'01': 'Recettes issues de la TEOM',
#   '02': 'Dotations et participations reçues',
#   '03': 'Autres recettes de fonctionnement éventuelles',
#   '05': "Remboursement d'emprunts et dettes assimilées",
#   '06': "Acquisitions d'immobilisations",
#   '07': 'Autres dépenses éventuelles',
#   '08': "Souscription d'emprunts et dettes assimilées",
#   '09': 'Dotations et subventions reçues',
#   '10': 'Autres recettes éventuelles',
#   '20': "Opérations d'équipements",
#   '21': 'Opérations pour comptes de tiers'},
#  'CodTypAgent': {'I': 'Titulaire', 'N': 'Non titulaires', 'R': 'Rattachement'},
#  'CodCatAgent': {'A': 'A', 'B': 'B', 'C': 'C'},
#  'NatureContrat': {'CDD': 'Contrat à durée déterminée',
#   'CDI': 'Contrat à durée indéterminée',
#   'A': 'Autres'},
#  'CodSectAgentTitulaire': {'ADM': 'Filière administrative',
#   'TECH': 'Technique',
#   'S': 'Sociale',
#   'MS': 'Médico-sociale',
#   'MT': 'Médico-technique',
#   'SP': 'Sportive',
#   'CULT': 'Culturelle',
#   'ANIM': 'Animation',
#   'POL': 'Police',
#   'POMP': 'Sapeurs-pompiers',
#   'X': 'Emplois non cités',
#   'DIR1': 'Directeur général des services',
#   'DIR2': 'Directeur général adjoint des services',
#   'DIR4': 'Directeur général des services techniques',
#   'DIR5': 'Emplois créés au titre de l’article L. 313-1 du CGFP',
#   'DIR6': 'Directeur départemental - SDIS',
#   'DIR7': 'Directeur départemental adjoint - SDIS',
#   'URB': 'Urbanisme'},
#  'CodSectAgentNonTitulaire': {'ADM': "Administratif (dont emplois de l'article 47 de la loi du 26/07/1984)",
#   'FIN': 'Financier',
#   'TECH': "Technique et informatique (dont emplois de l'article 47 de la loi du 26/07/1984)",
#   'URB': 'Urbanisme (dont aménagement urbain)',
#   'ENV': 'Environnement (dont espaces verts et aménagement rural)',
#   'COM': 'Communication',
#   'S': 'Social (dont aide sociale)',
#   'MS': 'Médico-Social',
#   'MT': 'Médico-Technique',
#   'SP': 'Sportif',
#   'CULT': 'Culturel (dont enseignement)',
#   'ANIM': 'Animation',
#   'RS': 'Restauration scolaire',
#   'ENT': 'Entretien',
#   'CAB': 'Collaborateurs de cabinet (article 110 de la loi du 26/01/1984)',
#   'X': 'Non cités'},
#  'CodMotifContrAgent': {'3-a°': {'z:libelle': 'Article 3, 1er alinéa',
#    'z:description': "accroissement temporaire d'activité"},
#   '3-b': {'z:libelle': 'Article 3, 2ème alinéa',
#    'z:description': "accroissement saisonnier d'activité"},
#   '3-1': "Remplacement d'un fonctionnaire autorisé à servir à temps partiel ou indisponible (maladie, maternité...)",
#   '3-2': "Vacance temporaire d'un emploi",
#   '3-3-1°': "Absence de cadre d'emplois de fonctionnaires susceptibles d'assurer les fonctions correspondantes",
#   '3-3-2°': 'Emplois du niveau de la catégorie A lorsque les besoins des services ou la nature des fonctions le justifient',
#   '3-3-3°': 'Emplois de secrétaire de mairie des communes de moins 1000 habitants et de secrétaire des groupements composés de communes dont la population moyenne est inférieur à ce seuil',
#   '3-3-4°': 'Emplois à temps non complet des communes de moins de 1000 habitants et des groupements composés de communes dont la population moyenne est inférieur à ce seuil, lorsque la quantité de temps de travail est inférieur à 50 %',
#   '3-3-5°': "Emplois des communes de moins de 2000 habitants dont la création ou la suppression dépend de la décision d'une autorité qui s'impose à la collectivité ou à l'établissement en matière de création, de changement de périmètre ou de suppression d'un service public",
#   '3-4': {'z:libelle': 'Article 21 de la loi n°2012-347',
#    'z:description': 'contrat à durée indéterminée obligatoirement proposée à un agent contractuel'},
#   '38': 'Article 38 travailleurs handicapés catégorie C',
#   '47': 'Article 47 recrutements directs sur emplois fonctionnels',
#   '110': 'Article 110 collaborateurs de groupes de cabinets',
#   '110-1': "Collaborateurs de groupes d'élus",
#   'A': 'Autres'},
#  'CodMotifRecrutement': {'332-23-1°': "Accroissement temporaire d'activité pour une durée maximale de douze mois.",
#   '332-23-2°': "Accroissement saisonnier d'activité pour une durée maximale de six mois.",
#   '332-24': "Contrat de projet pour une durée minimale d'un an et une durée maximale fixée par les parties dans la limite de six ans",
#   '332-13': 'Remplacement d’un fonctionnaire autorisé à servir à temps partiel ou indisponible.',
#   '332-14': 'Vacance temporaire d’un emploi.',
#   '332-8-1°': "Absence de cadre d'emplois de fonctionnaires susceptibles d'assurer les fonctions correspondantes.",
#   '332-8-2°': "Justifié par les besoins des services ou la nature des fonctions, sous réserve qu'aucun fonctionnaire territorial n'a pu être recruté dans les conditions prévues par le CGFP.",
#   '332-8-3°': 'Communes de moins de 1 000 hab. et groupements de communes regroupant moins de 15 000 hab.',
#   '332-8-4°': "Communes nouvelles issues de fusion de communes de moins de 1 000 hab., pendant trois ans suivant la création, le cas échéant, jusqu'au premier renouvellement du conseil municipal.",
#   '332-8-5°': "Autres collectivités territoriales ou établissements mentionnés à l'article L. 4, pour les emplois dont la quotité de temps de travail est inférieure à 50 %.",
#   '332-8-6°': "Emplois des communes (- 2 000 hab.) et des groupements de communes (-10 000 hab.) dont la création ou suppression dépend de la décision d'une autorité.",
#   '327-5': "Contractuel territorial sur emploi permanent - peut être nommé en qualité de fonctionnaire stagiaire par l'autorité territoriale.",
#   '332-10': "Contrat à durée indéterminée en application de l'article L. 332-8 avec un agent contractuel territorial qui justifie d'une durée de services publics de six ans au moins.",
#   '332-11': "Contrat à durée indéterminée lorsque l'agent contractuel territorial concerné remplit avant l'échéance de son contrat les conditions mentionnées à l'article L. 332-10.",
#   '326_352': "Modalités particulières : recrutement sans concours, parcours d'accès à la fonction publique, personnes en situation de handicap (CGFP art. L326 et L.352).",
#   '343-1_343-3': 'Emplois supérieurs de la fonction publique territoriale (emplois fonctionnels de direction).',
#   '333-1_333-10': 'Collaborateurs de cabinet.',
#   '333-12': "Collaborateurs de groupes d'élus.",
#   'A': 'Autres'},
#  'CodVariPatrim': {'01': 'CGCT',
#   '02': "Code de l'urbanisme",
#   '03': 'Bâtiments scolaires et administratifs',
#   '04': 'Construction, installation et agencements (hors bâtiments scolaires)',
#   '05': "Instalaltions techniques, matériels et outillage en cours d'amortissement",
#   '06': 'Autres immobilisations corporelles',
#   '07': 'Immobilisations incorporelles',
#   '10': 'Participations et créances rattachées à des participations',
#   '11': 'Autres immobilisations financières'},
#  'CodEntreeSorti': {'E': 'Entrée', 'S': 'Sortie'},
#  'CodModalAcqui': {'01': 'Acquisition à titre onéreux',
#   '02': 'Acquisition à titre gratuit',
#   '03': 'Affectation',
#   '04': 'Mise à disposition',
#   '05': 'Mise en concession ou affermage',
#   '99': 'Divers'},
#  'CodModalSorti': {'01': 'Cession à titre onéreux',
#   '02': 'Cession à titre gratuit',
#   '03': 'Affectation',
#   '04': 'Mise à disposition',
#   '05': 'Mise en concession ou affermage',
#   '06': 'Mise à la réforme',
#   '99': 'Divers'},
#  'CodTypImmo': {'I': 'Incorporelles', 'C': 'Corporelles', 'A': 'Autres'},
#  'CodTypTitre': {'261': 'Titres de participation',
#   '266': 'Autres formes de participations',
#   '271': 'Titres immobilisés (dt. propr.)',
#   '272': 'Titres immobilisés (dont créances)',
#   '276': 'Autres créances immobilisées'},
#  'CodNatOrgGroup': {'01': 'EPCI',
#   '02': 'Syndicats mixtes (article 5721-2 du CGCT)',
#   '03': 'Syndicats mixtes (article L5721-1 du CGCT)',
#   '09': 'Autres'},
#  'CodNatEng': {'01': 'Délégation de service public',
#   '02': "Détention d'une part de capital",
#   '03': "Garantie ou cautionnement d'un emprunt",
#   '04': 'Subventions',
#   '99': 'Autres'},
#  'CodTypBudAgreg': {'01': 'Budget principal',
#   '02': 'Budgets annexes',
#   '04': 'Flux réciproques entre le budget principal et les budgets annexes'},
#  'CodTypContrib': {'D': 'Directe', 'I': 'Indirecte'},
#  'CodSousTypContrib': {'01': "Taxe d'habitation",
#   '02': 'TFPB',
#   '03': 'TFPNB',
#   '04': 'Taxe professionnelle',
#   '05': "Taxe intérieure de consommation sur les produits énergétiques (part régionale définie à l'art. 265 du code des douanes)",
#   '06': 'Taxe sur les permis de conduire',
#   '07': "Taxe sur les certificats d'immatriculation des véhicules",
#   '08': 'Contribution foncière des entreprises',
#   '09': 'Taxe spéciale de consommation de produits pétroliers',
#   '10': 'Taxe sur le transport public aérien et maritime',
#   '11': "Taxe relative à l'octroi de mer",
#   '12': "Droits assimilés au droit d'octroi de mer auxquels sont soumis les rhums et spiritueux",
#   '13': 'Droit de francisation et de navigation corse',
#   '14': 'Droit de passeport en Corse',
#   '15': 'Droit de consommation sur les tabacs en Corse',
#   '16': "Taxe spéciale d'équipement",
#   '17': "Autres taxes pour lesquelles l'établissement a un pouvoir de modulation du taux",
#   '18': "Taxe destinée au financement des dépenses des conseils d'architecture, d'urbanisme et d'environnement",
#   '19': 'Taxe départementale des espaces naturels sensibles',
#   '20': "Taxe départementale de publicité foncière et droit départemental d'enregistrement",
#   '21': "Taxe sur la consommation finale d'électricité",
#   '22': 'Taxe sur les remontées mécaniques',
#   '23': "Taxe d'aménagement",
#   '24': "Taxe intérieure de consommation sur les produits énergétiques (majoration définie à l'art. 265 A bis du code des douanes)",
#   '25': 'Taxe d’habitation sur les résidences secondaires',
#   '99': 'Total'},
#  'CodTypeCarburant': {'01': 'SP', '02': 'Gazole'},
#  'Origine': {'1': 'Part régionale des ressources',
#   '2': 'Part départementale des ressources',
#   '3': 'Part communale des ressources'},
#  'CodNatJurBenefCA': {'P1': 'Associations',
#   'P2': 'Entreprises',
#   'P3': 'Personnes physiques',
#   'P4': 'Autres personnes de droit privé',
#   'U1': 'Régions',
#   'U2': 'Départements',
#   'U3': 'Communes',
#   'U4': 'Etablissements de droit public (EPCI, EPA, EPIC, ...)',
#   'U5': 'Etat',
#   'U6': 'Autres personnes de droit public'},
#  'CodTypAutEng': {'D': 'Donnés', 'R': 'Reçus'},
#  'CodArticle': {'5191': 'Avances du Trésor',
#   '5192': 'Avances de trésorerie',
#   '51921': 'Avances de la collectivité de rattachement',
#   '51928': 'Autre avances de trésorerie',
#   '51931': 'Lignes de crédits de trésorerie',
#   '51932': 'Lignes de trésorerie liées à un emprunt',
#   '5194': 'Billets de trésorerie',
#   '5198': 'Autres crédits de trésorerie'},
#  'CodTypPersoMorale': {'PART': 'Partenariat (EHB donnés)',
#   'DSP': 'Délégation service public (EHB donnés)',
#   'URB': 'Opérations d’urbanisme et d’aménagement (EHB donnés)',
#   'U': 'Autres org. publics (EHB donnés)',
#   'P': 'Autres org. privés (EHB donnés)',
#   'E': 'Entreprise (EHB reçus)',
#   'X': "à l'exception des entreprises (EHB reçus)"},
#  'CodSTypEng': {'PART': 'Partenariat (EHB donnés)',
#   'DSP': 'Délégation service public (EHB donnés)',
#   'URB': 'Opérations d’urbanisme et d’aménagement (EHB donnés)',
#   'U': 'Autres org. publics (EHB donnés)',
#   'P': 'Autres org. privés (EHB donnés)',
#   'E': 'Entreprise (EHB reçus)',
#   'X': "à l'exception des entreprises (EHB reçus)"},
#  'CodePeriod': {'M': 'Mensuelle',
#   'I': 'Trimestrielle',
#   'S': 'Semestrielle',
#   'A': 'Annuelle',
#   'X': 'Autre',
#   'B': 'Bimestrielle'},
#  'CodTypContr': {'I': 'Immobilier', 'M': 'Mobilier'},
#  'CodOperR': {'01': 'Financement par le mandant',
#   '02': 'Financement par le mandataire (ou le département ou la région)',
#   '03': 'Financement par emprunt à la charge du tiers (contrepartie D2763)',
#   '09': "Financement par d'autres tiers",
#   'A': 'Annulation sur exercices antérieurs'},
#  'TypOpDep': {'R': 'Opération réelle',
#   'OES': "Opération d'ordre entre sections",
#   'OIS': "Opération d'ordre à l'intérieur de la section",
#   'A': 'Annulation sur exercices antérieurs'},
#  'CodTypeCharge': {'01': 'Charges de fonctionnement à répartir (c/6812)',
#   '02': 'Charges financières à répartir (c/6862)'},
#  'CodTypEmpr': {'01': 'Normal',
#   '02': 'Emprunt pour autres organismes',
#   '05': 'Emprunt normal de refinancement',
#   '06': 'Emprunt normal refinancé',
#   '07': "Emprunt d'un autre organisme de refinancement",
#   '08': "Emprunt d'un autre organisme refinancé",
#   '09': 'Emprunt garanti',
#   '10': 'Eléments pour ratio'},
#  'CodProfilAmortDtVote': {'C': 'Amortissement constant',
#   'P': 'Amortissement progressif',
#   'F': 'In fine',
#   'X': 'Autre'},
#  'CodTypPreteur': {'01': 'Organismes de droit privé',
#   '02': 'Organismes de droit public',
#   '03': 'Emissions obligataires'},
#  'CodPeriodRembDtVote': {'M': 'Mensuelle',
#   'I': 'Trimestrielle',
#   'S': 'Semestrielle',
#   'A': 'Annuelle',
#   'X': 'Autre',
#   'B': 'Bimestrielle'},
#  'CodPeriodRembReneg': {'M': 'Mensuelle',
#   'I': 'Trimestrielle',
#   'S': 'Semestrielle',
#   'A': 'Annuelle',
#   'X': 'Autre',
#   'B': 'Bimestrielle'},
#  'CodTyptxDtVote': {'F': 'Fixe',
#   'V': 'Variable simple',
#   'R': 'Préfixé',
#   'C': 'Complexe'},
#  'CodTypEmprGaranti': {'01': 'contractés par des collectivités ou des EP (hors logements sociaux)',
#   '02': 'autres que ceux contractés par des collectivités ou des EP (hors logements sociaux)',
#   '03': "contractés pour des opérations de logements aidés par l'Etat",
#   '04': 'Autres emprunts garantis',
#   '05': 'contractés pour des opérations de logement social',
#   '99': 'Autres emprunts'},
#  'CodNatEmpr': {'F': 'Taux fixe sur toute la durée',
#   'I': 'Taux indexé sur toute la durée',
#   'P': 'Avec tranches',
#   'O': 'Avec options'},
#  'IndSousJacent': {'1': 'Indices en euro',
#   '2': 'Indices inflation française ou zone euro',
#   '3': 'Ecarts d’indice zone euro',
#   '4': 'Indices hors zone euro',
#   '5': 'Ecarts d’indice hors zone euro',
#   '6': 'Autres indices'},
#  'IndSousJacentDtVote': {'1': 'Indices en euro',
#   '2': 'Indices inflation française ou zone euro',
#   '3': 'Ecarts d’indice zone euro',
#   '4': 'Indices hors zone euro',
#   '5': 'Ecarts d’indice hors zone euro',
#   '6': 'Autres indices'},
#  'Structure': {'A': 'Taux fixe ou taux variable simple',
#   'B': 'Barrière simple',
#   'C': "Option d'échange (swap)",
#   'D': 'Multiplicateur jusqu’à 3 ou 5 capé',
#   'E': 'Multiplicateur jusqu’à 5',
#   'F': 'Autre type de structure'},
#  'StructureDtVote': {'A': 'Taux fixe ou taux variable simple',
#   'B': 'Barrière simple',
#   'C': "Option d'échange (swap)",
#   'D': 'Multiplicateur jusqu’à 3 ou 5 capé',
#   'E': 'Multiplicateur jusqu’à 5',
#   'F': 'Autre type de structure'},
#  'TypeSortie': {'A': 'Autofinancement',
#   'C': 'Capitalisation',
#   'I': 'Intégration dans le taux du nouvel emprunt',
#   'D': 'Allongement de durée'},
#  'CodTypTxCouv': {'F': 'Fixe', 'V': 'Variable', 'C': 'Complexe'},
#  'CodTypTxReneg': {'F': 'Fixe',
#   'V': 'Variable simple',
#   'R': 'Préfixé',
#   'C': 'Complexe'},
#  'CodProfilAmortReneg': {'C': 'Amortissement constant',
#   'P': 'Amortissement progressif',
#   'F': 'In fine',
#   'X': 'Autre'}}
